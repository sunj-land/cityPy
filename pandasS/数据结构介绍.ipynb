# %%
import numpy as np
import pandas as pd

# %%
np.random.randn(5)
# Out:
# array([ 0.91807617, -0.75453513,  0.27967871,  0.09469149,  1.84039902])

# %%
s1 = pd.Series({
    "a":1,
    "b":2
})
s1
s1+s1
# Out:
# a    2
# b    4
# dtype: int64

# %%
df = pd.DataFrame({
    "one":[1,1,1],
    "two":[2,2,2]
})

df["three"] = df["one"]+df["two"]
df["foo"] = "foo"
df.insert(1,"bar",[4,2,4])
type(df.values)
# Out:
# numpy.ndarray

# %%
pd.set_option("display.width", 20)
pd.DataFrame(np.random.randn(3, 100))
# Out:
#          0   \
# 0 -1.461895
# 1 -0.562583
# 2 -0.853297
#
#          1   \
# 0  0.273067
# 1 -0.463132
# 2  0.069440
#
#          2   \
# 0 -0.367065
# 1 -0.644512
# 2  1.151175
#
#          3   \
# 0  1.650695
# 1  1.089140
# 2  0.393137
#
#          4   \
# 0  0.274397
# 1 -0.523251
# 2  0.386713
#
#          5   \
# 0 -0.789275
# 1 -1.760662
# 2 -1.673963
#
#          6   \
# 0  1.718026
# 1  0.642456
# 2 -0.288307
#
#          7   \
# 0 -0.199710
# 1  0.295215
# 2 -0.165516
#
#          8   \
# 0  0.302860
# 1  1.606102
# 2 -0.332407
#
#          9   ...  \
# 0 -0.437928  ...
# 1  0.417947  ...
# 2  0.033588  ...
#
#          90  \
# 0 -0.829312
# 1 -0.856844
# 2  0.320362
#
#          91  \
# 0  0.283443
# 1 -0.837077
# 2  0.311645
#
#          92  \
# 0  1.359805
# 1  0.649794
# 2  0.441271
#
#          93  \
# 0  0.778609
# 1  0.296359
# 2  0.808538
#
#          94  \
# 0  1.930340
# 1 -0.411617
# 2  1.010304
#
#          95  \
# 0 -0.811490
# 1  0.763712
# 2 -0.609479
#
# ...
