# %%
import numpy as np
import pandas as pd

# %%
index = pd.date_range("1/1/2000",periods=6,freq="h")
index
# Out:
# DatetimeIndex(['2000-01-01 00:00:00', '2000-01-01 01:00:00',
#                '2000-01-01 02:00:00', '2000-01-01 03:00:00',
#                '2000-01-01 04:00:00', '2000-01-01 05:00:00'],
#               dtype='datetime64[ns]', freq='h')

# %%
s = pd.Series(np.random.randn(5),index=list("abcde"))
s
# Out:
# a   -1.253211
# b   -0.180198
# c   -0.555487
# d    1.430822
# e   -2.518148
# dtype: float64

# %%
df = pd.DataFrame(np.random.randn(6,3),index=index,columns=list("ABC"))
df
# Out:
#                             A         B         C
# 2000-01-01 00:00:00  0.049903 -0.689743  0.046116
# 2000-01-01 01:00:00 -0.452357  2.114372  0.563977
# 2000-01-01 02:00:00 -0.296161  0.464995 -0.507263
# 2000-01-01 03:00:00  0.774680  0.271086  0.789291
# 2000-01-01 04:00:00  1.818416  0.905570  1.239388
# 2000-01-01 05:00:00 -1.627688  0.365248 -2.014741

# %%
df.head(2)
df.tail(2)
df[:2]
# Out:
#                             A         B         C
# 2000-01-01 00:00:00  0.049903 -0.689743  0.046116
# 2000-01-01 01:00:00 -0.452357  2.114372  0.563977

# %%
df.shape
# Out:
# (6, 3)

# %%
df.columns = [x.lower() for x in df.columns]
df
# Out:
#                             a         b         c
# 2000-01-01 00:00:00  0.049903 -0.689743  0.046116
# 2000-01-01 01:00:00 -0.452357  2.114372  0.563977
# 2000-01-01 02:00:00 -0.296161  0.464995 -0.507263
# 2000-01-01 03:00:00  0.774680  0.271086  0.789291
# 2000-01-01 04:00:00  1.818416  0.905570  1.239388
# 2000-01-01 05:00:00 -1.627688  0.365248 -2.014741

# %%
df.to_numpy()
df_np = np.asarray(df)
np.may_share_memory(df.values,df_np)
# Out:
# True

# %%
pd.Series(pd.date_range("2000", periods=2, tz="CET"))
# Out:
# 0   2000-01-01 00:00:00+01:00
# 1   2000-01-02 00:00:00+01:00
# dtype: datetime64[ns, CET]

# %%
df = pd.DataFrame(
    {
        "one": pd.Series(np.random.randn(3), index=["a", "b", "c"]),
        "two": pd.Series(np.random.randn(4), index=["a", "b", "c", "d"]),
        "three": pd.Series(np.random.randn(3), index=["b", "c", "d"]),
    }
)
df
# Out:
#         one       two     three
# a  0.237941  1.402817       NaN
# b -0.486523 -0.647907  1.076648
# c  1.271302 -1.088699 -0.708575
# d       NaN -1.217484 -0.623805

# %%
row = df.iloc[1]
row
# Out:
# one     -0.486523
# two     -0.647907
# three    1.076648
# Name: b, dtype: float64

# %%
column = df["two"]
column
# Out:
# a    1.402817
# b   -0.647907
# c   -1.088699
# d   -1.217484
# Name: two, dtype: float64

# %%
df.sub(row,axis="columns")
df.sub(row,axis=1)
# Out:
#         one       two     three
# a  0.724464  2.050724       NaN
# b  0.000000  0.000000  0.000000
# c  1.757825 -0.440792 -1.785224
# d       NaN -0.569577 -1.700454

# %%
df.sub(column,axis=0)
df.sub(column,axis="index")
# Out:
#         one  two     three
# a -1.164877  0.0       NaN
# b  0.161384  0.0  1.724555
# c  2.360001  0.0  0.380123
# d       NaN  0.0  0.593678

# %%
df2 = df.copy()
df2
# Out:
#         one       two     three
# a  0.237941  1.402817       NaN
# b -0.486523 -0.647907  1.076648
# c  1.271302 -1.088699 -0.708575
# d       NaN -1.217484 -0.623805

# %%
df2.loc["a","three"] = 1.0
df2
# Out:
#         one       two     three
# a  0.237941  1.402817  1.000000
# b -0.486523 -0.647907  1.076648
# c  1.271302 -1.088699 -0.708575
# d       NaN -1.217484 -0.623805

# %%
df
# Out:
#         one       two     three
# a  0.237941  1.402817       NaN
# b -0.486523 -0.647907  1.076648
# c  1.271302 -1.088699 -0.708575
# d       NaN -1.217484 -0.623805

# %%
df+df2
# Out:
#         one       two     three
# a  0.475881  2.805634       NaN
# b -0.973046 -1.295813  2.153297
# c  2.542604 -2.177397 -1.417151
# d       NaN -2.434967 -1.247611

# %%
df.add(df2,fill_value=0)
# Out:
#         one       two     three
# a  0.475881  2.805634  1.000000
# b -0.973046 -1.295813  2.153297
# c  2.542604 -2.177397 -1.417151
# d       NaN -2.434967 -1.247611

# %%
df.eq(df2)
# Out:
#      one   two  three
# a   True  True  False
# b   True  True   True
# c   True  True   True
# d  False  True   True

# %%
df>0
# Out:
#      one    two  three
# a   True   True  False
# b  False  False   True
# c   True  False  False
# d  False  False  False

# %%
(df>0).any()
# Out:
# one      True
# two      True
# three    True
# dtype: bool

# %%
np.nan == np.nan
# Out:
# False

# %%
(df+df).equals(df*2)
# Out:
# True

# %%
(df+df==df*2).all().all()
# Out:
# False

# %%
pd.Series(["foo", "bar", "baz"]) == pd.Index(["foo", "bar", "qux"])
# Out:
# 0     True
# 1     True
# 2    False
# dtype: bool

# %%
df
# Out:
#         one       two     three
# a  0.237941  1.402817       NaN
# b -0.486523 -0.647907  1.076648
# c  1.271302 -1.088699 -0.708575
# d       NaN -1.217484 -0.623805

# %%
df.sum(axis=0,skipna=True)
# Out:
# one      1.022720
# two     -1.551272
# three   -0.255732
# dtype: float64

# %%
df.sum(axis=1,skipna=True)
# Out:
# a    1.640758
# b   -0.057781
# c   -0.525972
# d   -1.841289
# dtype: float64

# %%
df.sum(axis=1,skipna=True)
# Out:
# a    1.640758
# b   -0.057781
# c   -0.525972
# d   -1.841289
# dtype: float64

# %%
df
# Out:
#         one       two     three
# a  0.237941  1.402817       NaN
# b -0.486523 -0.647907  1.076648
# c  1.271302 -1.088699 -0.708575
# d       NaN -1.217484 -0.623805

# %%
df.mean(0)
# Out:
# one      0.340907
# two     -0.387818
# three   -0.085244
# dtype: float64

# %%
df-df.mean()
# Out:
#         one       two     three
# a -0.102966  1.790635       NaN
# b -0.827430 -0.260089  1.161893
# c  0.930396 -0.700881 -0.623331
# d       NaN -0.829666 -0.538561

# %%
df.std()
# Out:
# one      0.883425
# two      1.218414
# three    1.007121
# dtype: float64

# %%
df.cumsum(skipna=True)
# Out:
#         one       two     three
# a  0.237941  1.402817       NaN
# b -0.248582  0.754911  1.076648
# c  1.022720 -0.333788  0.368073
# d       NaN -1.551272 -0.255732

# %%
df.count()
# Out:
# one      3
# two      4
# three    3
# dtype: int64

# %%
df.describe()
# Out:
#             one       two     three
# count  3.000000  4.000000  3.000000
# mean   0.340907 -0.387818 -0.085244
# std    0.883425  1.218414  1.007121
# min   -0.486523 -1.217484 -0.708575
# 25%   -0.124291 -1.120895 -0.666190
# 50%    0.237941 -0.868303 -0.623805
# 75%    0.754621 -0.135226  0.226422
# max    1.271302  1.402817  1.076648

# %%
s = pd.Series(["a", "a", "b", "b", "a", "a", np.nan, "c", "d", "a"])
s.describe()
# Out:
# count     9
# unique    4
# top       a
# freq      5
# dtype: object

# %%
frame = pd.DataFrame({"a": ["Yes", "Yes", "No", "No"], "b": range(4)})
frame
# Out:
#      a  b
# 0  Yes  0
# 1  Yes  1
# 2   No  2
# 3   No  3

# %%
frame.describe()
# Out:
#               b
# count  4.000000
# mean   1.500000
# std    1.290994
# min    0.000000
# 25%    0.750000
# 50%    1.500000
# 75%    2.250000
# max    3.000000

# %%
s1 = pd.Series(np.random.randn(5))
s1
# Out:
# 0   -2.142825
# 1    1.949919
# 2   -0.440903
# 3    0.753364
# 4    0.663010
# dtype: float64

# %%
s1.idxmin
# Out:
# <bound method Series.idxmin of 0   -2.142825
# 1    1.949919
# 2   -0.440903
# 3    0.753364
# 4    0.663010
# dtype: float64>

# %%
data = np.random.randint(0, 7, size=50)
s = pd.Series(data)
s.value_counts()
# Out:
# 5    14
# 4     8
# 6     8
# 0     7
# 1     6
# 3     5
# 2     2
# Name: count, dtype: int64

# %%
s5 = pd.Series([1, 1, 3, 3, 3, 5, 5, 7, 7, 7])
s5.mode()
# Out:
# 0    3
# 1    7
# dtype: int64

# %%
arr = np.random.randn(20)
arr
# Out:
# array([-0.61775216,  1.95383396, -0.17297942, -2.74527806, -1.51903712,
#        -1.91418513,  0.11160013, -0.60720409,  2.30818257,  0.66148321,
#         0.93532347, -0.83094168,  0.6737884 , -2.05958439, -0.49243315,
#         1.14142026,  1.08219051, -0.95189588, -0.87951289, -0.92569205])

# %%
factor = pd.cut(arr,4)
factor
# Out:
# [(-1.482, -0.219], (1.045, 2.308], (-0.219, 1.045], (-2.75, -1.482], (-2.75, -1.482], ..., (1.045, 2.308], (1.045, 2.308], (-1.482, -0.219], (-1.482, -0.219], (-1.482, -0.219]]
# Length: 20
# Categories (4, interval[float64, right]): [(-2.75, -1.482] < (-1.482, -0.219] < (-0.219, 1.045] < (1.045, 2.308]]

# %%
n = 20
tsdf = pd.DataFrame(
    np.random.randn(n,3),
    columns=list("ABC"),
    index = pd.date_range("1/1/2000", periods=n)
)
tsdf.apply(lambda x:x.idxmax())
# Out:
# A   2001-09-09
# B   2001-01-16
# C   2000-08-04
# dtype: datetime64[ns]

# %%
tsdf.axes
# Out:
# [DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                 '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                 '2000-01-09', '2000-01-10',
#                 ...
#                 '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                 '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                 '2002-09-25', '2002-09-26'],
#                dtype='datetime64[ns]', length=1000, freq='D'),
#  Index(['A', 'B', 'C'], dtype='object')]

# %%
for rowi,row in tsdf.iterrows():
    print(rowi)
    print(row)
    print(type(row))
    print("=============")
# Out:
# 2000-01-01 00:00:00
# A   -1.454186
# B   -0.531196
# C    0.651094
# Name: 2000-01-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-02 00:00:00
# A   -0.884233
# B    0.550045
# C   -0.967938
# Name: 2000-01-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-03 00:00:00
# A    2.080842
# B    0.107802
# C    0.475696
# Name: 2000-01-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-04 00:00:00
# A   -0.153550
# B    1.021853
# C   -0.700834
# Name: 2000-01-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-05 00:00:00
# A    0.347161
# B   -0.078305
# C    1.318502
# Name: 2000-01-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-06 00:00:00
# A   -1.311778
# B   -0.025724
# C   -1.082506
# Name: 2000-01-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-07 00:00:00
# A   -0.441127
# B   -0.073991
# C   -0.042957
# Name: 2000-01-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-08 00:00:00
# A   -1.033476
# B    1.614066
# C    0.735309
# Name: 2000-01-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-09 00:00:00
# A   -0.375442
# B   -0.526831
# C    0.161498
# Name: 2000-01-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-10 00:00:00
# A    0.034862
# B    0.615330
# C   -0.404996
# Name: 2000-01-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-11 00:00:00
# A    1.252138
# B    0.081389
# C    1.015882
# Name: 2000-01-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-12 00:00:00
# A   -1.320458
# B    0.761003
# C   -0.074747
# Name: 2000-01-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-13 00:00:00
# A    0.332458
# B   -0.397143
# C    1.106818
# Name: 2000-01-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-14 00:00:00
# A    0.886702
# B    1.401673
# C    1.039370
# Name: 2000-01-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-15 00:00:00
# A    1.316040
# B   -0.325488
# C   -0.638920
# Name: 2000-01-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-16 00:00:00
# A   -0.476443
# B   -0.622399
# C   -0.392635
# Name: 2000-01-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-17 00:00:00
# A   -0.941045
# B   -0.677465
# C   -0.131477
# Name: 2000-01-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-18 00:00:00
# A   -1.143630
# B    0.770831
# C   -1.070893
# Name: 2000-01-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-19 00:00:00
# A    0.744264
# B    0.000445
# C    0.740124
# Name: 2000-01-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-20 00:00:00
# A    0.05770
# B    0.15089
# C    0.01631
# Name: 2000-01-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-21 00:00:00
# A    1.557653
# B   -0.419481
# C   -0.295475
# Name: 2000-01-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-22 00:00:00
# A   -0.456116
# B   -0.622223
# C   -0.654009
# Name: 2000-01-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-23 00:00:00
# A   -1.060900
# B    0.097201
# C    0.065977
# Name: 2000-01-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-24 00:00:00
# A    0.890253
# B   -0.925186
# C    1.245532
# Name: 2000-01-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-25 00:00:00
# A   -0.461723
# B   -0.175645
# C    0.698712
# Name: 2000-01-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-26 00:00:00
# A    0.177711
# B    0.291497
# C    1.446865
# Name: 2000-01-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-27 00:00:00
# A   -0.957636
# B    0.792760
# C   -0.103654
# Name: 2000-01-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-28 00:00:00
# A    0.866790
# B   -0.721319
# C   -0.888514
# Name: 2000-01-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-29 00:00:00
# A   -0.358817
# B    1.071506
# C    0.314248
# Name: 2000-01-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-30 00:00:00
# A   -0.684624
# B   -1.099403
# C    0.863653
# Name: 2000-01-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-01-31 00:00:00
# A    1.058412
# B   -0.525006
# C   -0.002472
# Name: 2000-01-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-01 00:00:00
# A   -1.199482
# B   -0.423023
# C    0.894981
# Name: 2000-02-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-02 00:00:00
# A   -0.076409
# B    0.323264
# C   -0.114670
# Name: 2000-02-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-03 00:00:00
# A    0.393059
# B    0.019259
# C    1.135786
# Name: 2000-02-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-04 00:00:00
# A   -0.544369
# B    1.307964
# C    0.183649
# Name: 2000-02-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-05 00:00:00
# A   -0.772052
# B    0.226922
# C    1.881524
# Name: 2000-02-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-06 00:00:00
# A    0.528091
# B    1.143724
# C   -1.276948
# Name: 2000-02-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-07 00:00:00
# A    0.553580
# B   -0.437408
# C   -0.190838
# Name: 2000-02-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-08 00:00:00
# A   -1.334454
# B   -0.174742
# C    0.418700
# Name: 2000-02-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-09 00:00:00
# A    0.256094
# B   -0.671567
# C    0.548206
# Name: 2000-02-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-10 00:00:00
# A   -1.806914
# B    1.140725
# C   -0.746980
# Name: 2000-02-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-11 00:00:00
# A    0.523133
# B    0.422794
# C    0.010964
# Name: 2000-02-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-12 00:00:00
# A   -0.337383
# B    0.401197
# C   -1.041963
# Name: 2000-02-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-13 00:00:00
# A    0.334665
# B   -0.808507
# C    0.082232
# Name: 2000-02-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-14 00:00:00
# A   -0.512471
# B   -0.208241
# C    0.156566
# Name: 2000-02-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-15 00:00:00
# A   -0.073594
# B   -0.449178
# C    1.614809
# Name: 2000-02-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-16 00:00:00
# A    0.107693
# B   -0.072953
# C   -1.542474
# Name: 2000-02-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-17 00:00:00
# A   -0.527898
# B   -0.616622
# C    0.181905
# Name: 2000-02-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-18 00:00:00
# A   -0.329454
# B   -0.610816
# C   -0.130788
# Name: 2000-02-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-19 00:00:00
# A   -0.170980
# B   -0.421325
# C   -0.483849
# Name: 2000-02-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-20 00:00:00
# A   -0.483358
# B    0.945335
# C    0.434253
# Name: 2000-02-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-21 00:00:00
# A   -0.157322
# B    0.610297
# C   -0.852123
# Name: 2000-02-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-22 00:00:00
# A    1.173936
# B    0.153279
# C   -0.274037
# Name: 2000-02-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-23 00:00:00
# A    1.394238
# B   -0.347288
# C    1.155427
# Name: 2000-02-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-24 00:00:00
# A    0.672127
# B    1.088541
# C    1.964206
# Name: 2000-02-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-25 00:00:00
# A    0.402781
# B    0.983755
# C   -0.629096
# Name: 2000-02-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-26 00:00:00
# A   -0.102689
# B    0.097039
# C   -1.358198
# Name: 2000-02-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-27 00:00:00
# A   -1.744639
# B    1.303322
# C    0.580230
# Name: 2000-02-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-28 00:00:00
# A   -1.068542
# B   -0.983417
# C   -1.322830
# Name: 2000-02-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-02-29 00:00:00
# A    2.314334
# B    2.091389
# C    0.604124
# Name: 2000-02-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-01 00:00:00
# A   -0.351757
# B   -0.875841
# C   -1.027633
# Name: 2000-03-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-02 00:00:00
# A   -2.434076
# B   -1.071836
# C   -0.873431
# Name: 2000-03-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-03 00:00:00
# A    0.213509
# B   -0.231757
# C   -1.550991
# Name: 2000-03-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-04 00:00:00
# A   -0.893350
# B   -2.291531
# C    1.402964
# Name: 2000-03-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-05 00:00:00
# A   -0.935136
# B   -2.590343
# C    0.106782
# Name: 2000-03-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-06 00:00:00
# A    0.963926
# B    1.780689
# C    0.689058
# Name: 2000-03-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-07 00:00:00
# A    0.181219
# B    1.385497
# C   -0.667942
# Name: 2000-03-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-08 00:00:00
# A    0.725233
# B   -0.547398
# C    0.512711
# Name: 2000-03-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-09 00:00:00
# A    0.262789
# B    1.231444
# C   -0.605216
# Name: 2000-03-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-10 00:00:00
# A   -0.014266
# B    0.343830
# C   -1.238108
# Name: 2000-03-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-11 00:00:00
# A   -0.103718
# B    0.101309
# C    0.585153
# Name: 2000-03-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-12 00:00:00
# A    0.229569
# B    0.223419
# C   -0.147733
# Name: 2000-03-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-13 00:00:00
# A    0.292093
# B    1.180386
# C    1.486234
# Name: 2000-03-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-14 00:00:00
# A    0.615918
# B    0.122636
# C    0.343391
# Name: 2000-03-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-15 00:00:00
# A    1.005635
# B    0.243096
# C   -0.402057
# Name: 2000-03-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-16 00:00:00
# A   -0.074859
# B   -0.214097
# C   -0.313502
# Name: 2000-03-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-17 00:00:00
# A    0.709190
# B    0.416582
# C    0.039939
# Name: 2000-03-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-18 00:00:00
# A    0.269326
# B   -1.543797
# C   -0.645896
# Name: 2000-03-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-19 00:00:00
# A    1.336540
# B   -1.495851
# C   -1.279916
# Name: 2000-03-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-20 00:00:00
# A   -0.779486
# B   -0.493619
# C    0.351476
# Name: 2000-03-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-21 00:00:00
# A   -0.479278
# B    1.438426
# C   -0.173199
# Name: 2000-03-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-22 00:00:00
# A    0.065381
# B    0.330501
# C   -0.731643
# Name: 2000-03-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-23 00:00:00
# A    0.102929
# B    1.167422
# C    0.426111
# Name: 2000-03-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-24 00:00:00
# A    0.739897
# B    0.536057
# C   -0.447254
# Name: 2000-03-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-25 00:00:00
# A   -0.126240
# B    0.677858
# C    1.428455
# Name: 2000-03-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-26 00:00:00
# A   -0.486617
# B    0.242010
# C   -1.692874
# Name: 2000-03-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-27 00:00:00
# A   -1.245029
# B   -1.478359
# C    2.101516
# Name: 2000-03-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-28 00:00:00
# A   -1.566211
# B    0.160136
# C    1.509901
# Name: 2000-03-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-29 00:00:00
# A   -1.291431
# B   -1.367563
# C    0.428166
# Name: 2000-03-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-30 00:00:00
# A    1.059808
# B    0.519390
# C   -0.367462
# Name: 2000-03-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-03-31 00:00:00
# A    0.717485
# B   -1.264720
# C   -0.096572
# Name: 2000-03-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-01 00:00:00
# A   -1.356006
# B    0.902634
# C   -0.834794
# Name: 2000-04-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-02 00:00:00
# A    0.161875
# B    0.871803
# C   -0.360602
# Name: 2000-04-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-03 00:00:00
# A   -0.608851
# B   -0.166057
# C    1.339684
# Name: 2000-04-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-04 00:00:00
# A    1.003844
# B    0.406354
# C    0.749696
# Name: 2000-04-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-05 00:00:00
# A    0.692166
# B   -1.649764
# C    0.886282
# Name: 2000-04-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-06 00:00:00
# A    0.372402
# B    0.522915
# C   -0.148552
# Name: 2000-04-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-07 00:00:00
# A   -1.153755
# B    0.476694
# C   -1.128142
# Name: 2000-04-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-08 00:00:00
# A   -2.193695
# B   -0.212043
# C    0.245034
# Name: 2000-04-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-09 00:00:00
# A   -0.713350
# B   -0.541516
# C    0.737485
# Name: 2000-04-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-10 00:00:00
# A   -0.508937
# B   -0.060306
# C   -0.750325
# Name: 2000-04-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-11 00:00:00
# A    0.777249
# B   -2.258007
# C   -0.392725
# Name: 2000-04-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-12 00:00:00
# A    1.403903
# B   -0.374371
# C   -0.062328
# Name: 2000-04-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-13 00:00:00
# A   -1.042117
# B   -1.094860
# C    0.441734
# Name: 2000-04-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-14 00:00:00
# A    1.363907
# B    0.373093
# C   -0.202634
# Name: 2000-04-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-15 00:00:00
# A    0.561379
# B    2.464740
# C    1.300779
# Name: 2000-04-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-16 00:00:00
# A    0.299522
# B    0.478279
# C    0.778537
# Name: 2000-04-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-17 00:00:00
# A   -1.002051
# B    1.073547
# C   -0.105883
# Name: 2000-04-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-18 00:00:00
# A   -0.722240
# B   -0.380952
# C    0.436832
# Name: 2000-04-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-19 00:00:00
# A    0.110258
# B   -1.420315
# C    0.162889
# Name: 2000-04-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-20 00:00:00
# A   -0.160130
# B    0.064736
# C    0.514286
# Name: 2000-04-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-21 00:00:00
# A   -1.132306
# B   -0.074793
# C    0.754887
# Name: 2000-04-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-22 00:00:00
# A   -0.077745
# B    0.965801
# C    1.016168
# Name: 2000-04-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-23 00:00:00
# A   -2.487830
# B    0.393650
# C    0.363079
# Name: 2000-04-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-24 00:00:00
# A   -1.171135
# B    0.311746
# C   -0.185047
# Name: 2000-04-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-25 00:00:00
# A    1.159054
# B   -0.898352
# C   -0.583479
# Name: 2000-04-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-26 00:00:00
# A    0.247157
# B    0.280796
# C   -1.393478
# Name: 2000-04-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-27 00:00:00
# A   -0.803323
# B   -0.214816
# C    1.507960
# Name: 2000-04-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-28 00:00:00
# A   -0.382903
# B    0.036397
# C    0.547715
# Name: 2000-04-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-29 00:00:00
# A    1.547646
# B   -0.788277
# C   -0.628333
# Name: 2000-04-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-04-30 00:00:00
# A   -0.858240
# B    0.683940
# C   -0.090561
# Name: 2000-04-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-01 00:00:00
# A   -0.285412
# B   -0.316653
# C   -1.135220
# Name: 2000-05-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-02 00:00:00
# A    0.278463
# B   -0.718596
# C   -0.494158
# Name: 2000-05-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-03 00:00:00
# A   -0.589986
# B   -0.230845
# C   -2.355822
# Name: 2000-05-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-04 00:00:00
# A    1.724696
# B   -1.299636
# C   -0.355862
# Name: 2000-05-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-05 00:00:00
# A   -1.581197
# B   -0.814944
# C   -0.970399
# Name: 2000-05-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-06 00:00:00
# A   -0.935272
# B    1.610550
# C    1.405003
# Name: 2000-05-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-07 00:00:00
# A   -1.233853
# B    0.288685
# C   -0.344448
# Name: 2000-05-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-08 00:00:00
# A   -0.300111
# B    0.506995
# C   -0.183247
# Name: 2000-05-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-09 00:00:00
# A   -0.387947
# B    1.526229
# C   -0.142456
# Name: 2000-05-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-10 00:00:00
# A   -0.447122
# B    0.782891
# C    0.073271
# Name: 2000-05-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-11 00:00:00
# A    1.049028
# B   -0.539294
# C   -0.680436
# Name: 2000-05-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-12 00:00:00
# A    0.368564
# B   -0.062033
# C   -1.048244
# Name: 2000-05-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-13 00:00:00
# A    0.037359
# B   -1.497809
# C   -0.130555
# Name: 2000-05-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-14 00:00:00
# A    1.695119
# B    0.294004
# C   -0.013312
# Name: 2000-05-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-15 00:00:00
# A   -1.102389
# B    0.614972
# C    0.589839
# Name: 2000-05-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-16 00:00:00
# A   -0.141658
# B    2.035633
# C    0.944668
# Name: 2000-05-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-17 00:00:00
# A    0.283428
# B    0.557920
# C    1.115042
# Name: 2000-05-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-18 00:00:00
# A   -1.516262
# B   -1.776866
# C    0.529695
# Name: 2000-05-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-19 00:00:00
# A   -1.950225
# B    1.119298
# C   -1.057141
# Name: 2000-05-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-20 00:00:00
# A   -0.594703
# B   -1.527983
# C   -0.619901
# Name: 2000-05-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-21 00:00:00
# A    1.285790
# B    0.026312
# C    0.012660
# Name: 2000-05-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-22 00:00:00
# A    0.312699
# B    0.083544
# C   -0.273437
# Name: 2000-05-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-23 00:00:00
# A   -0.761493
# B   -1.130890
# C    1.159709
# Name: 2000-05-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-24 00:00:00
# A   -0.433587
# B   -0.175447
# C   -0.968839
# Name: 2000-05-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-25 00:00:00
# A    1.950835
# B    0.309140
# C    1.223757
# Name: 2000-05-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-26 00:00:00
# A    1.414147
# B   -0.654943
# C   -0.498801
# Name: 2000-05-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-27 00:00:00
# A   -1.375168
# B    0.304557
# C    1.535992
# Name: 2000-05-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-28 00:00:00
# A   -2.197083
# B    1.706474
# C    0.239498
# Name: 2000-05-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-29 00:00:00
# A   -0.839105
# B   -0.107461
# C    0.287582
# Name: 2000-05-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-30 00:00:00
# A    1.203037
# B    1.026015
# C   -1.133948
# Name: 2000-05-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-05-31 00:00:00
# A   -0.212835
# B   -0.221455
# C   -0.628173
# Name: 2000-05-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-01 00:00:00
# A   -1.906891
# B   -2.097421
# C   -0.246725
# Name: 2000-06-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-02 00:00:00
# A   -1.341299
# B   -1.036500
# C    0.661926
# Name: 2000-06-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-03 00:00:00
# A   -0.951843
# B   -1.630753
# C    0.510247
# Name: 2000-06-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-04 00:00:00
# A    0.435160
# B   -1.887358
# C   -0.925919
# Name: 2000-06-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-05 00:00:00
# A    0.302744
# B    1.346227
# C    0.497917
# Name: 2000-06-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-06 00:00:00
# A   -0.484212
# B   -0.122109
# C    0.570584
# Name: 2000-06-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-07 00:00:00
# A   -1.390162
# B    0.113137
# C    0.172024
# Name: 2000-06-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-08 00:00:00
# A   -0.222638
# B   -0.827713
# C   -1.624296
# Name: 2000-06-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-09 00:00:00
# A    0.884304
# B   -0.969570
# C    0.302631
# Name: 2000-06-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-10 00:00:00
# A    0.024645
# B    0.509471
# C   -1.132277
# Name: 2000-06-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-11 00:00:00
# A   -1.025999
# B    2.346398
# C   -0.791152
# Name: 2000-06-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-12 00:00:00
# A    0.421945
# B    1.248132
# C    0.336135
# Name: 2000-06-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-13 00:00:00
# A    0.300392
# B   -0.256624
# C   -0.007229
# Name: 2000-06-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-14 00:00:00
# A   -0.788597
# B    0.231219
# C   -0.026315
# Name: 2000-06-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-15 00:00:00
# A    0.475561
# B   -0.674794
# C    1.051238
# Name: 2000-06-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-16 00:00:00
# A    0.920501
# B   -1.019564
# C    0.867944
# Name: 2000-06-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-17 00:00:00
# A    0.111979
# B   -0.324221
# C    1.071828
# Name: 2000-06-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-18 00:00:00
# A   -1.726418
# B   -2.758533
# C    0.337634
# Name: 2000-06-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-19 00:00:00
# A   -1.737983
# B    1.161706
# C   -0.551803
# Name: 2000-06-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-20 00:00:00
# A   -1.125772
# B    0.908903
# C    0.655087
# Name: 2000-06-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-21 00:00:00
# A   -0.790397
# B    1.052574
# C    1.954563
# Name: 2000-06-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-22 00:00:00
# A    0.475954
# B   -1.148046
# C   -2.954958
# Name: 2000-06-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-23 00:00:00
# A    0.321230
# B   -0.951280
# C    0.302764
# Name: 2000-06-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-24 00:00:00
# A   -1.478106
# B   -1.018942
# C    0.045324
# Name: 2000-06-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-25 00:00:00
# A   -1.159081
# B    1.401706
# C    1.555045
# Name: 2000-06-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-26 00:00:00
# A    0.774783
# B   -0.322733
# C   -2.202922
# Name: 2000-06-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-27 00:00:00
# A    1.760546
# B   -0.471766
# C    1.663101
# Name: 2000-06-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-28 00:00:00
# A    0.499876
# B    0.544325
# C   -1.252999
# Name: 2000-06-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-29 00:00:00
# A   -0.811411
# B   -2.028194
# C    0.204193
# Name: 2000-06-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-06-30 00:00:00
# A    0.842296
# B   -0.055983
# C    0.417977
# Name: 2000-06-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-01 00:00:00
# A   -0.756974
# B    1.840244
# C    0.009535
# Name: 2000-07-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-02 00:00:00
# A   -1.183270
# B   -0.824291
# C    0.458512
# Name: 2000-07-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-03 00:00:00
# A   -0.929110
# B   -1.457470
# C    0.775622
# Name: 2000-07-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-04 00:00:00
# A   -0.431383
# B   -1.500001
# C    0.742551
# Name: 2000-07-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-05 00:00:00
# A   -1.107364
# B    1.051991
# C   -1.457676
# Name: 2000-07-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-06 00:00:00
# A    0.036648
# B    1.152855
# C   -0.513856
# Name: 2000-07-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-07 00:00:00
# A    0.247730
# B   -0.968529
# C   -1.330354
# Name: 2000-07-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-08 00:00:00
# A   -0.414488
# B   -1.245901
# C    0.271652
# Name: 2000-07-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-09 00:00:00
# A    0.729426
# B    1.201636
# C    0.159113
# Name: 2000-07-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-10 00:00:00
# A   -1.355824
# B   -0.027898
# C   -0.900396
# Name: 2000-07-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-11 00:00:00
# A   -1.210390
# B    1.022257
# C   -1.239838
# Name: 2000-07-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-12 00:00:00
# A    1.860190
# B    1.486695
# C   -0.892453
# Name: 2000-07-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-13 00:00:00
# A   -0.692732
# B   -1.435362
# C    1.005185
# Name: 2000-07-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-14 00:00:00
# A   -2.173660
# B   -0.573214
# C   -0.025874
# Name: 2000-07-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-15 00:00:00
# A    0.567486
# B   -0.901555
# C   -1.429440
# Name: 2000-07-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-16 00:00:00
# A   -1.348892
# B   -0.665037
# C    1.539030
# Name: 2000-07-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-17 00:00:00
# A   -1.282130
# B   -2.183372
# C    1.009603
# Name: 2000-07-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-18 00:00:00
# A    0.219123
# B   -0.044239
# C   -1.067373
# Name: 2000-07-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-19 00:00:00
# A   -0.626809
# B    0.039100
# C   -0.102092
# Name: 2000-07-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-20 00:00:00
# A    0.587765
# B   -0.069338
# C    0.434677
# Name: 2000-07-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-21 00:00:00
# A    0.341826
# B   -0.393912
# C   -0.090866
# Name: 2000-07-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-22 00:00:00
# A   -1.068228
# B   -0.573986
# C    0.573131
# Name: 2000-07-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-23 00:00:00
# A    0.558342
# B   -0.853668
# C    1.552966
# Name: 2000-07-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-24 00:00:00
# A    0.446196
# B    0.137064
# C    0.778496
# Name: 2000-07-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-25 00:00:00
# A   -1.207252
# B    1.506551
# C   -0.745561
# Name: 2000-07-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-26 00:00:00
# A   -0.723633
# B    1.052860
# C   -2.223906
# Name: 2000-07-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-27 00:00:00
# A    0.714106
# B   -1.064605
# C   -0.009693
# Name: 2000-07-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-28 00:00:00
# A    1.235738
# B    1.467850
# C   -0.624858
# Name: 2000-07-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-29 00:00:00
# A   -1.613268
# B    1.457932
# C   -0.895203
# Name: 2000-07-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-30 00:00:00
# A    1.221123
# B   -0.055003
# C   -0.501640
# Name: 2000-07-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-07-31 00:00:00
# A   -0.061578
# B   -1.245301
# C   -1.154880
# Name: 2000-07-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-01 00:00:00
# A    0.452493
# B    0.107550
# C   -0.867145
# Name: 2000-08-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-02 00:00:00
# A    0.493646
# B   -0.383062
# C    0.052136
# Name: 2000-08-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-03 00:00:00
# A    0.249824
# B   -1.382825
# C   -0.533315
# Name: 2000-08-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-04 00:00:00
# A    0.285400
# B   -1.624193
# C    3.101736
# Name: 2000-08-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-05 00:00:00
# A    0.948842
# B   -1.729625
# C   -1.949324
# Name: 2000-08-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-06 00:00:00
# A   -0.691541
# B   -0.918180
# C   -1.230804
# Name: 2000-08-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-07 00:00:00
# A   -0.713034
# B   -1.238799
# C   -0.430335
# Name: 2000-08-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-08 00:00:00
# A   -0.244949
# B    1.337796
# C    0.365372
# Name: 2000-08-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-09 00:00:00
# A    0.643685
# B   -1.132000
# C   -0.975431
# Name: 2000-08-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-10 00:00:00
# A    1.458331
# B    0.160607
# C    0.825255
# Name: 2000-08-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-11 00:00:00
# A   -0.305311
# B   -1.289187
# C   -0.708018
# Name: 2000-08-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-12 00:00:00
# A   -0.691686
# B   -1.418093
# C   -0.346544
# Name: 2000-08-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-13 00:00:00
# A    1.566853
# B    0.058866
# C   -1.112682
# Name: 2000-08-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-14 00:00:00
# A   -0.389293
# B   -1.023858
# C    0.940534
# Name: 2000-08-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-15 00:00:00
# A   -1.634548
# B    1.014809
# C   -0.224301
# Name: 2000-08-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-16 00:00:00
# A    0.753880
# B    0.705072
# C    0.598461
# Name: 2000-08-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-17 00:00:00
# A   -0.998006
# B    0.263713
# C   -1.419603
# Name: 2000-08-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-18 00:00:00
# A   -1.066207
# B   -1.448007
# C    0.913219
# Name: 2000-08-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-19 00:00:00
# A   -0.447435
# B    0.263694
# C   -1.405727
# Name: 2000-08-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-20 00:00:00
# A    0.650965
# B   -0.494103
# C    0.388055
# Name: 2000-08-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-21 00:00:00
# A    1.846391
# B   -0.411890
# C    0.630390
# Name: 2000-08-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-22 00:00:00
# A    0.500744
# B   -1.143513
# C   -0.021538
# Name: 2000-08-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-23 00:00:00
# A   -0.137705
# B   -1.748315
# C   -0.223909
# Name: 2000-08-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-24 00:00:00
# A    2.112461
# B   -0.472081
# C    0.901431
# Name: 2000-08-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-25 00:00:00
# A   -1.452449
# B    1.234714
# C   -1.184533
# Name: 2000-08-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-26 00:00:00
# A    3.047048
# B    0.268627
# C    1.742314
# Name: 2000-08-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-27 00:00:00
# A    0.437503
# B   -0.264566
# C   -0.886734
# Name: 2000-08-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-28 00:00:00
# A   -0.710953
# B   -1.456207
# C    1.210242
# Name: 2000-08-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-29 00:00:00
# A   -0.341801
# B   -1.057428
# C    1.477494
# Name: 2000-08-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-30 00:00:00
# A    0.262872
# B    0.430441
# C   -1.128160
# Name: 2000-08-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-08-31 00:00:00
# A   -0.411366
# B   -0.766156
# C    0.318085
# Name: 2000-08-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-01 00:00:00
# A   -0.070508
# B    0.277022
# C   -2.401681
# Name: 2000-09-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-02 00:00:00
# A    0.406418
# B    0.727996
# C    0.111398
# Name: 2000-09-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-03 00:00:00
# A   -0.895302
# B   -1.023062
# C   -0.840629
# Name: 2000-09-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-04 00:00:00
# A   -1.339921
# B   -0.538555
# C    1.435712
# Name: 2000-09-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-05 00:00:00
# A    0.599632
# B   -0.897695
# C    0.229701
# Name: 2000-09-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-06 00:00:00
# A   -0.580580
# B    0.290156
# C    0.119216
# Name: 2000-09-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-07 00:00:00
# A   -1.530861
# B    0.139562
# C   -0.968182
# Name: 2000-09-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-08 00:00:00
# A    0.128647
# B    1.520023
# C    0.763041
# Name: 2000-09-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-09 00:00:00
# A    1.273414
# B   -0.254428
# C    0.003213
# Name: 2000-09-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-10 00:00:00
# A   -1.691733
# B    1.006098
# C    0.025098
# Name: 2000-09-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-11 00:00:00
# A   -1.668142
# B    0.697687
# C   -0.635398
# Name: 2000-09-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-12 00:00:00
# A    0.765894
# B    0.553559
# C   -0.227696
# Name: 2000-09-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-13 00:00:00
# A   -0.799434
# B   -0.059142
# C    1.053082
# Name: 2000-09-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-14 00:00:00
# A   -0.245577
# B   -1.439241
# C    0.346664
# Name: 2000-09-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-15 00:00:00
# A   -0.594683
# B    1.098383
# C   -0.378546
# Name: 2000-09-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-16 00:00:00
# A    0.776607
# B    1.338392
# C   -0.534313
# Name: 2000-09-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-17 00:00:00
# A   -0.414910
# B    0.697698
# C    0.740785
# Name: 2000-09-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-18 00:00:00
# A   -1.474493
# B    1.249202
# C   -0.677765
# Name: 2000-09-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-19 00:00:00
# A   -0.773920
# B   -0.078157
# C   -0.722788
# Name: 2000-09-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-20 00:00:00
# A   -0.020295
# B   -1.125777
# C    0.832353
# Name: 2000-09-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-21 00:00:00
# A   -0.640042
# B    1.719647
# C   -0.548396
# Name: 2000-09-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-22 00:00:00
# A    0.951319
# B    1.416504
# C    1.197377
# Name: 2000-09-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-23 00:00:00
# A    2.133338
# B   -0.273786
# C    3.013507
# Name: 2000-09-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-24 00:00:00
# A    0.162781
# B    1.332396
# C    0.594993
# Name: 2000-09-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-25 00:00:00
# A    0.081334
# B    0.204417
# C   -1.260314
# Name: 2000-09-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-26 00:00:00
# A    0.516692
# B   -0.196651
# C    0.180577
# Name: 2000-09-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-27 00:00:00
# A   -0.373899
# B    0.839455
# C   -1.685418
# Name: 2000-09-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-28 00:00:00
# A   -0.365087
# B   -1.335890
# C   -0.510527
# Name: 2000-09-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-29 00:00:00
# A   -1.271956
# B    0.252042
# C    1.741973
# Name: 2000-09-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-09-30 00:00:00
# A   -0.046654
# B    0.590131
# C    2.260315
# Name: 2000-09-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-01 00:00:00
# A    0.344981
# B   -0.411609
# C    0.239732
# Name: 2000-10-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-02 00:00:00
# A   -0.534122
# B   -0.333528
# C   -1.037033
# Name: 2000-10-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-03 00:00:00
# A    0.354416
# B   -0.422478
# C    1.179213
# Name: 2000-10-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-04 00:00:00
# A    2.374783
# B    1.432999
# C   -0.529822
# Name: 2000-10-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-05 00:00:00
# A    0.523953
# B    1.797175
# C    0.718519
# Name: 2000-10-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-06 00:00:00
# A   -1.602827
# B   -1.398846
# C    1.881699
# Name: 2000-10-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-07 00:00:00
# A   -1.475256
# B    0.476241
# C    0.159119
# Name: 2000-10-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-08 00:00:00
# A    0.607852
# B    0.784637
# C   -1.433582
# Name: 2000-10-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-09 00:00:00
# A   -0.032290
# B    0.538821
# C   -0.074439
# Name: 2000-10-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-10 00:00:00
# A   -0.421675
# B    0.413473
# C    0.792741
# Name: 2000-10-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-11 00:00:00
# A   -0.667574
# B    2.154840
# C   -0.980096
# Name: 2000-10-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-12 00:00:00
# A   -1.067343
# B   -0.196352
# C   -0.783750
# Name: 2000-10-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-13 00:00:00
# A   -0.818320
# B    0.854386
# C   -0.452046
# Name: 2000-10-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-14 00:00:00
# A    0.970061
# B   -1.526067
# C   -0.870337
# Name: 2000-10-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-15 00:00:00
# A    0.581474
# B   -0.191346
# C    0.277928
# Name: 2000-10-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-16 00:00:00
# A    0.806349
# B    0.210966
# C    1.080490
# Name: 2000-10-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-17 00:00:00
# A   -0.196552
# B   -0.450921
# C   -1.034635
# Name: 2000-10-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-18 00:00:00
# A    0.702888
# B   -0.604339
# C    0.355766
# Name: 2000-10-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-19 00:00:00
# A    0.279752
# B   -0.702232
# C   -0.144941
# Name: 2000-10-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-20 00:00:00
# A   -1.589888
# B   -1.143019
# C    0.415289
# Name: 2000-10-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-21 00:00:00
# A    0.391188
# B    0.366505
# C   -0.476224
# Name: 2000-10-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-22 00:00:00
# A   -0.879958
# B   -0.698173
# C    1.329537
# Name: 2000-10-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-23 00:00:00
# A   -0.046495
# B   -0.447407
# C    1.903069
# Name: 2000-10-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-24 00:00:00
# A    1.849976
# B    0.582275
# C   -0.070835
# Name: 2000-10-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-25 00:00:00
# A    0.454265
# B    0.132064
# C    0.498582
# Name: 2000-10-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-26 00:00:00
# A    1.392698
# B   -0.764446
# C    1.063401
# Name: 2000-10-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-27 00:00:00
# A   -0.287267
# B   -0.343290
# C   -0.195127
# Name: 2000-10-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-28 00:00:00
# A    0.665757
# B    0.645800
# C    1.450908
# Name: 2000-10-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-29 00:00:00
# A    0.685381
# B    0.024223
# C    1.234139
# Name: 2000-10-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-30 00:00:00
# A   -0.788518
# B    0.154282
# C    0.632073
# Name: 2000-10-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-10-31 00:00:00
# A    2.046446
# B    0.003336
# C    0.483900
# Name: 2000-10-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-11-01 00:00:00
# A   -1.017780
# B    1.239646
# C   -1.336901
# Name: 2000-11-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-11-02 00:00:00
# A   -0.133003
# B    1.008560
# C    0.954559
# Name: 2000-11-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-11-03 00:00:00
# A   -0.055918
# B    0.809108
# C   -0.128531
# Name: 2000-11-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-11-04 00:00:00
# A    0.214024
# B    0.753703
# C   -1.417634
# Name: 2000-11-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-11-05 00:00:00
# A    1.068113
# B    0.550731
# C    1.798404
# Name: 2000-11-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-11-06 00:00:00
# A   -0.152991
# B    0.923410
# C    0.128272
# Name: 2000-11-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2000-11-07 00:00:00
# A    0.526151
# B    0.055184
# C   -1.222153
# Name: 2000-11-07 00:00:00, dtype: float64
# ...
# A   -0.492825
# B    0.326968
# C   -0.126480
# Name: 2002-06-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-16 00:00:00
# A    1.063167
# B    0.657145
# C   -0.171100
# Name: 2002-06-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-17 00:00:00
# A   -1.368704
# B   -0.879130
# C    1.674477
# Name: 2002-06-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-18 00:00:00
# A    1.058559
# B    1.066170
# C    1.069299
# Name: 2002-06-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-19 00:00:00
# A   -0.171385
# B   -0.801015
# C    0.281848
# Name: 2002-06-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-20 00:00:00
# A   -1.366569
# B   -0.012632
# C   -2.529427
# Name: 2002-06-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-21 00:00:00
# A    1.512079
# B    0.746537
# C    0.268690
# Name: 2002-06-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-22 00:00:00
# A   -0.083079
# B    0.420648
# C    0.176701
# Name: 2002-06-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-23 00:00:00
# A    0.406737
# B    0.936209
# C    0.399654
# Name: 2002-06-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-24 00:00:00
# A    0.022225
# B   -0.377624
# C   -0.010957
# Name: 2002-06-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-25 00:00:00
# A    0.506922
# B   -1.339659
# C    1.118621
# Name: 2002-06-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-26 00:00:00
# A   -0.275198
# B    1.082734
# C   -1.079306
# Name: 2002-06-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-27 00:00:00
# A    0.208497
# B   -0.416231
# C   -1.603444
# Name: 2002-06-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-28 00:00:00
# A    1.700176
# B   -0.214021
# C    2.379447
# Name: 2002-06-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-29 00:00:00
# A   -0.296883
# B    0.546975
# C    0.064281
# Name: 2002-06-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-06-30 00:00:00
# A   -0.506074
# B    0.862725
# C   -0.250766
# Name: 2002-06-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-01 00:00:00
# A   -0.464475
# B    0.751504
# C    2.219026
# Name: 2002-07-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-02 00:00:00
# A   -1.357857
# B    0.388208
# C    0.177138
# Name: 2002-07-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-03 00:00:00
# A   -0.245879
# B   -0.358976
# C    0.499825
# Name: 2002-07-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-04 00:00:00
# A    0.498864
# B   -0.578003
# C    0.851117
# Name: 2002-07-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-05 00:00:00
# A   -0.141911
# B    1.140781
# C    0.271419
# Name: 2002-07-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-06 00:00:00
# A   -0.834841
# B   -0.705102
# C    0.679733
# Name: 2002-07-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-07 00:00:00
# A   -0.009227
# B   -0.039167
# C    0.029932
# Name: 2002-07-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-08 00:00:00
# A    0.210339
# B    0.341434
# C    0.560745
# Name: 2002-07-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-09 00:00:00
# A    2.116687
# B   -0.420181
# C   -0.778399
# Name: 2002-07-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-10 00:00:00
# A    1.492390
# B    1.299027
# C   -0.468991
# Name: 2002-07-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-11 00:00:00
# A   -1.400357
# B    0.134243
# C    0.493591
# Name: 2002-07-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-12 00:00:00
# A   -0.679116
# B   -0.073958
# C    0.910538
# Name: 2002-07-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-13 00:00:00
# A    0.163733
# B   -1.344041
# C    0.202103
# Name: 2002-07-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-14 00:00:00
# A    1.614763
# B    0.350091
# C   -0.440480
# Name: 2002-07-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-15 00:00:00
# A   -0.409660
# B   -0.377503
# C    0.240466
# Name: 2002-07-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-16 00:00:00
# A   -0.202149
# B    1.145179
# C   -1.200515
# Name: 2002-07-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-17 00:00:00
# A   -0.402774
# B    0.095239
# C    0.041394
# Name: 2002-07-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-18 00:00:00
# A   -0.651995
# B    0.008553
# C    0.627717
# Name: 2002-07-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-19 00:00:00
# A   -2.031095
# B    1.672455
# C   -0.762287
# Name: 2002-07-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-20 00:00:00
# A   -1.117917
# B   -0.756727
# C   -0.190094
# Name: 2002-07-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-21 00:00:00
# A   -0.358179
# B    0.757729
# C    0.755057
# Name: 2002-07-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-22 00:00:00
# A    0.412986
# B   -0.472653
# C    1.457026
# Name: 2002-07-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-23 00:00:00
# A   -0.456462
# B   -0.526427
# C    0.290959
# Name: 2002-07-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-24 00:00:00
# A    0.069419
# B    0.530387
# C    0.254207
# Name: 2002-07-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-25 00:00:00
# A   -0.106176
# B   -0.990227
# C   -2.161130
# Name: 2002-07-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-26 00:00:00
# A    0.563323
# B   -0.232537
# C    0.177995
# Name: 2002-07-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-27 00:00:00
# A    0.307926
# B    0.207050
# C   -1.709833
# Name: 2002-07-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-28 00:00:00
# A    1.371989
# B    1.767384
# C    2.077816
# Name: 2002-07-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-29 00:00:00
# A    0.654217
# B    1.361242
# C    0.251972
# Name: 2002-07-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-30 00:00:00
# A   -0.190786
# B    0.183047
# C    0.549398
# Name: 2002-07-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-07-31 00:00:00
# A   -0.664926
# B   -0.711357
# C   -0.345441
# Name: 2002-07-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-01 00:00:00
# A    0.382336
# B    0.555866
# C   -1.102925
# Name: 2002-08-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-02 00:00:00
# A   -1.106398
# B   -0.552733
# C    0.299611
# Name: 2002-08-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-03 00:00:00
# A   -0.367176
# B   -1.338274
# C   -0.034982
# Name: 2002-08-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-04 00:00:00
# A   -2.019758
# B    0.244212
# C   -2.828881
# Name: 2002-08-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-05 00:00:00
# A    0.875533
# B   -0.811915
# C   -0.801464
# Name: 2002-08-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-06 00:00:00
# A   -0.536673
# B   -0.021249
# C   -0.946195
# Name: 2002-08-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-07 00:00:00
# A    0.619665
# B    0.331619
# C   -0.669522
# Name: 2002-08-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-08 00:00:00
# A   -0.770297
# B   -0.528208
# C   -0.126942
# Name: 2002-08-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-09 00:00:00
# A    0.033439
# B    0.084497
# C   -1.830099
# Name: 2002-08-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-10 00:00:00
# A    0.913681
# B   -0.804209
# C    0.799873
# Name: 2002-08-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-11 00:00:00
# A    1.932500
# B   -1.036810
# C   -1.691854
# Name: 2002-08-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-12 00:00:00
# A   -0.819375
# B   -2.751606
# C   -0.222893
# Name: 2002-08-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-13 00:00:00
# A   -0.898433
# B   -0.884983
# C    1.355292
# Name: 2002-08-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-14 00:00:00
# A    0.282316
# B    1.124337
# C   -0.312400
# Name: 2002-08-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-15 00:00:00
# A   -0.795471
# B    0.289134
# C   -0.168816
# Name: 2002-08-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-16 00:00:00
# A    0.203931
# B    0.243237
# C   -0.596753
# Name: 2002-08-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-17 00:00:00
# A    0.628041
# B    0.872203
# C    0.560102
# Name: 2002-08-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-18 00:00:00
# A   -0.543491
# B   -0.927677
# C   -0.238999
# Name: 2002-08-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-19 00:00:00
# A   -0.968489
# B   -1.698960
# C   -1.729815
# Name: 2002-08-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-20 00:00:00
# A   -0.148892
# B    0.756098
# C   -1.199697
# Name: 2002-08-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-21 00:00:00
# A    0.286038
# B    0.938551
# C    0.093750
# Name: 2002-08-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-22 00:00:00
# A   -0.088327
# B   -0.715942
# C    0.051958
# Name: 2002-08-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-23 00:00:00
# A   -0.427065
# B    0.549676
# C    0.462496
# Name: 2002-08-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-24 00:00:00
# A    1.275082
# B   -0.456502
# C   -1.061490
# Name: 2002-08-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-25 00:00:00
# A    1.138453
# B   -0.089529
# C   -0.242949
# Name: 2002-08-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-26 00:00:00
# A   -0.991326
# B    0.886817
# C   -0.628286
# Name: 2002-08-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-27 00:00:00
# A   -0.001296
# B    0.889949
# C    1.772679
# Name: 2002-08-27 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-28 00:00:00
# A   -0.508958
# B   -1.398021
# C    0.814579
# Name: 2002-08-28 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-29 00:00:00
# A    0.466321
# B   -0.298625
# C   -1.031496
# Name: 2002-08-29 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-30 00:00:00
# A    1.245442
# B    0.754748
# C   -0.227699
# Name: 2002-08-30 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-08-31 00:00:00
# A    0.061982
# B    0.465001
# C   -0.181713
# Name: 2002-08-31 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-01 00:00:00
# A    0.299269
# B   -1.150707
# C    1.799455
# Name: 2002-09-01 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-02 00:00:00
# A   -1.574242
# B   -0.784934
# C   -0.465406
# Name: 2002-09-02 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-03 00:00:00
# A    0.840542
# B    1.438661
# C    0.565074
# Name: 2002-09-03 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-04 00:00:00
# A    0.339943
# B   -0.137932
# C    0.443768
# Name: 2002-09-04 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-05 00:00:00
# A   -0.188456
# B   -1.499370
# C    1.377371
# Name: 2002-09-05 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-06 00:00:00
# A    0.649467
# B    1.067829
# C    0.031495
# Name: 2002-09-06 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-07 00:00:00
# A    0.510574
# B    0.222529
# C    0.224551
# Name: 2002-09-07 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-08 00:00:00
# A   -0.717232
# B   -0.275141
# C    0.370196
# Name: 2002-09-08 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-09 00:00:00
# A   -0.270328
# B    0.839995
# C   -0.337695
# Name: 2002-09-09 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-10 00:00:00
# A    0.725308
# B    0.371951
# C    2.588992
# Name: 2002-09-10 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-11 00:00:00
# A    0.106528
# B    0.996911
# C   -2.724297
# Name: 2002-09-11 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-12 00:00:00
# A   -0.995457
# B    1.976636
# C   -1.403742
# Name: 2002-09-12 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-13 00:00:00
# A    1.061553
# B   -1.093392
# C    1.275981
# Name: 2002-09-13 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-14 00:00:00
# A   -2.853219
# B    0.182987
# C    0.679277
# Name: 2002-09-14 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-15 00:00:00
# A    2.127165
# B   -0.298723
# C   -0.490414
# Name: 2002-09-15 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-16 00:00:00
# A    0.514802
# B    0.414897
# C   -0.174141
# Name: 2002-09-16 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-17 00:00:00
# A    0.226268
# B   -0.369625
# C    0.028765
# Name: 2002-09-17 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-18 00:00:00
# A   -0.695133
# B   -0.489634
# C    0.198166
# Name: 2002-09-18 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-19 00:00:00
# A   -0.224510
# B    1.299815
# C    0.909690
# Name: 2002-09-19 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-20 00:00:00
# A   -0.850504
# B    0.969624
# C   -0.509510
# Name: 2002-09-20 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-21 00:00:00
# A    0.019290
# B   -0.856061
# C   -1.147490
# Name: 2002-09-21 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-22 00:00:00
# A    0.165153
# B   -0.147749
# C    0.865839
# Name: 2002-09-22 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-23 00:00:00
# A   -0.124990
# B    0.617487
# C   -0.352494
# Name: 2002-09-23 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-24 00:00:00
# A    0.792186
# B   -0.028815
# C   -2.159786
# Name: 2002-09-24 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-25 00:00:00
# A   -0.935513
# B    0.199777
# C    1.533791
# Name: 2002-09-25 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
# 2002-09-26 00:00:00
# A    0.037824
# B   -0.315177
# C    0.315216
# Name: 2002-09-26 00:00:00, dtype: float64
# <class 'pandas.core.series.Series'>
# =============
