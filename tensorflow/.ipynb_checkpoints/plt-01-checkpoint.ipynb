# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2 * np.pi, 200)
y = np.sin(x)

fig, ax = plt.subplots()
ax.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 生成数据
x = np.linspace(0, 10, 100)
y = np.sin(x)

# 创建 Figure 和 Axes
fig, axs = plt.subplots(2,2,figsize=(10,10))

type(axs)

((ax1,ax2),(ax3,ax4)) = axs
# # 绘制折线图
out = ax1.plot(x, y,color='red',linestyle='--',linewidth=2)
out
# type(out)
# # 设置标题和坐标轴标签
# ax1.set_title('Sine Wave')
# ax1.set_xlabel('X1')
# ax1.set_ylabel('Y')

# ax2.plot(x, y,color='red',linestyle='--',linewidth=2)
# ax2.set_title('Sine Wave')
# ax2.set_xlabel('X1')
# ax2.set_ylabel('Y')

# plt.tight_layout()

# # 显示图表
# plt.show()

# %%
import numpy as np

#np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data,maker='s')
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
data['c']
# np.random.randn(50)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 10
#       7 data['b'] = data['a'] + 10 * np.random.randn(50)
#       8 data['d'] = np.abs(data['d']) * 100
# ---> 10 fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained',maker='s')
#      11 ax.scatter('a', 'b', c='c', s='d', data=data)
#      12 ax.set_xlabel('entry a')
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:1775, in subplots(nrows, ncols, sharex, sharey, squeeze, width_ratios, height_ratios, subplot_kw, gridspec_kw, **fig_kw)
#    1620 def subplots(
#    1621     nrows: int = 1, ncols: int = 1, *,
#    1622     sharex: bool | Literal["none", "all", "row", "col"] = False,
#    (...)   1629     **fig_kw
#    1630 ) -> tuple[Figure, Any]:
#    1631     """
#    1632     Create a figure and a set of subplots.
#    1633
#    (...)   1773
#    1774     """
# -> 1775     fig = figure(**fig_kw)
#    1776     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1777                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1778                        gridspec_kw=gridspec_kw, height_ratios=height_ratios,
#    1779                        width_ratios=width_ratios)
#    1780     return fig, axs
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:1042, in figure(num, figsize, dpi, facecolor, edgecolor, frameon, FigureClass, clear, **kwargs)
#    1032 if len(allnums) == max_open_warning >= 1:
#    1033     _api.warn_external(
#    1034         f"More than {max_open_warning} figures have been opened. "
#    1035         f"Figures created through the pyplot interface "
#    (...)   1039         f"Consider using `matplotlib.pyplot.close()`.",
#    1040         RuntimeWarning)
# -> 1042 manager = new_figure_manager(
#    1043     num, figsize=figsize, dpi=dpi,
#    1044     facecolor=facecolor, edgecolor=edgecolor, frameon=frameon,
#    1045     FigureClass=FigureClass, **kwargs)
#    1046 fig = manager.canvas.figure
#    1047 if fig_label:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/pyplot.py:552, in new_figure_manager(*args, **kwargs)
#     550 """Create a new figure manager instance."""
#     551 _warn_if_gui_out_of_main_thread()
# --> 552 return _get_backend_mod().new_figure_manager(*args, **kwargs)
#
# File ~/Library/Python/3.12/lib/python/site-packages/matplotlib_inline/backend_inline.py:27, in new_figure_manager(num, FigureClass, *args, **kwargs)
#      21 def new_figure_manager(num, *args, FigureClass=Figure, **kwargs):
#      22     """
#      23     Return a new figure manager for a new figure instance.
#      24
#      25     This function is part of the API expected by Matplotlib backends.
#      26     """
# ---> 27     return new_figure_manager_given_figure(num, FigureClass(*args, **kwargs))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/figure.py:2560, in Figure.__init__(self, figsize, dpi, facecolor, edgecolor, linewidth, frameon, subplotpars, tight_layout, constrained_layout, layout, **kwargs)
#    2464 def __init__(self,
#    2465              figsize=None,
#    2466              dpi=None,
#    (...)   2476              **kwargs
#    2477              ):
#    2478     """
#    2479     Parameters
#    2480     ----------
#    (...)   2558         %(Figure:kwdoc)s
#    2559     """
# -> 2560     super().__init__(**kwargs)
#    2561     self._root_figure = self
#    2562     self._layout_engine = None
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/figure.py:154, in FigureBase.__init__(self, **kwargs)
#     152 self.stale = True
#     153 self.suppressComposite = None
# --> 154 self.set(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/matplotlib/artist.py:1206, in Artist._update_props(self, props, errfmt)
#    1204             func = getattr(self, f"set_{k}", None)
#    1205             if not callable(func):
# -> 1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
#    1209             ret.append(func(v))
#    1210 if ret:
#
# AttributeError: Figure.set() got an unexpected keyword argument 'maker'
